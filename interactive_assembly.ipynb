# %%
################### import packages ##########################################
import pandas as pd
import re
import numpy as np
import os
import copy 
import fnmatch
# %load_ext line_profiler
pd.set_option('display.max_columns', None)

##############################################################################
####### choose variables to look for from codebooks ###########################
##############################################################################

# make sure these are all lowercase!!! #####################

# for HRS core files, 2002 - present
#SELECT VARIABLES OF INTEREST

variables_to_look_for = { 'a500':'rmonth_survey'
                         , 'a501':'ryear_survey'
                         , 'x026m':'state_live'
                         , 'x060_r':'gender'
                         , 'x067_r':'year_born'
                         , 'a019':'age'
                         , 'a028':'live_nursing_facility'
                         , 'a066':'state_nursing_facility'
                         , 'a068m':'year_born'
                         , 'b002':'born_us' #1 yes, #5 no
                         , 'b005m':'country_born' #1 yes, #5 no
                         , 'b003m':'state_born'
                         , 'b014':'education'
                         , 'b017m':'highest_degree'
                         , 'b028':'race_latino_hispanic'
                         , 'b031a':'race'
                         , 'q020':'income'
                         , 'b033':'num_children'
                        , 'b050':'religion'
                         , 'marital':'marital_status'
                         , 'b058':'divorce_widow_status'
                         ,'c115':'exercise'
                         , 'c001':'health_status' #1 excellent, 5 poor
                         , 'c002':'health_status_compared_to_prev'
                          , 'c003':'health_status_better_compared_to_prev_degree'
, 'c004':'health_status_worse_compared_to_prev_degree'
, 'c005':'high_blood_pressure'
, 'c009':'high_blood_pressure_compared_to_prev'
, 'c010':'diabetes'
, 'c016':'diabetes_compared_to_prev'
, 'c018':'cancer'
, 'c023':'cancer_compared_to_prev'
, 'c030':'lung_disease'
, 'c031':'lung_disease_compared_to_prev'
, 'c036':'heart_condition'
, 'c039':'heart_condition_compared_to_prev'
, 'c053':'stroke'
, 'c055':'heart_condition_compared_to_prev'
, 'c065':'psychiatric_emotional_problem'
, 'c066':'psychiatric_emotional_problem_compared_to_prev'
, 'c070':'arthritis'
, 'c071':'arthritis_compared_to_prev'
, 'c104':'pain'
, 'c105':'pain_degree'
, 'c116':'smoke'
, 'c117':'still_smoke'
, 'c128':'alcohol'
, 'c129':'num_drinks_days_per_week'
, 'c130':'num_drinks_per_day'
, 'c144':'shortness_breath'
, 'c148':'fatigue'
, 'c149':'cough'
, 'c150':'depressed'
, 'c154':'tired'
, 'c155':'appetite_loss'
, 'c156':'appetite_increase'
, 'd101':'memory' #1 good, 5 poor
, 'd110':'depressed' #1 yes, #5 no
, 'e012':'children_nearby'
  , 'e118':'dependents'
            , 'e119':'num_dependents'             
                         , 'h002':'type_house'
                         , 'h004':'own_or_rent'
                         , 'h020':'property_value'
                         , 'h070':'year_property_acquired'
                         , 'j005m1':'employment_status'
                         , 'j018':'year_retired'
                       , 'p004':'financial_expectation'
                       , 'p007':'leave_inheritance'
                       , 'q481':'debt_amount'
                       , '005':'vocab_level'
                       , '034':'friendliness'
                       , '035':'attentiveness'
                       , '037':'cooperation'
                       , '038':'tiredness'
                       , '040':'memory'
                       , '041':'hearing'
                         }


# for HRS core files, pre 2002
# 2000 has g's, 1998 has f's, 1996 has e's, 1994 has w's, 1992 has v's
variables_to_look_for_pre_2002 = {
      'g775': 'rmonth_survey'
    , 'f704': 'rmonth_survey'
    , 'e391': 'rmonth_survey'
    , 'w120': 'rmonth_survey'
    , 'v128': 'rmonth_survey'
    , 'g774': 'ryear_survey'
    , 'f703': 'ryear_survey'
    , 'e393': 'ryear_survey'
    , 'w122': 'ryear_survey'
    , 'v127': 'ryear_survey'
    , 'g4996': 'rpr_lose_job'
    , 'f4583': 'rpr_lose_job'
    , 'e3788': 'rpr_lose_job'
    , 'w5801': 'rpr_lose_job' 
    , 'v3205': 'rpr_lose_job'    
}

# for CAMS core files
CAMS_variables = { 'b1': 'rauto_pur_f' 
                , 'b2': 'rrefrig_pur_f' 
                , 'b3': 'rwasherdrier_pur_f'
                , 'b4': 'rdishwasher_pur_f'
                , 'b5': 'rtv_pur_f'}

# for HRS Rand file, choose patterns
#* is a wildcard for wave, so gets it for all waves
hrs_patterns = ['r*mstat', 'r*agey_b', 'h*itot']

# for HRS Rand file, choose patterns
#cams_patterns = ['h*ctots', 'h*cdurs', 'h*cndur', 'h*ctotc']
cams_patterns = ['h*cctots', 'h*ccdurs', 'h*ccdur', 'h*ctot']

# %%
# this is an extension of the sas_read_year function to work across multiple years
# for all years specified, gets all variables specified from the HRS core files

# input types:
# years :  list
# directory : string
# variables_to_look_for : dictionary
# variables_to_look_for_pre_2002 : dictionary

def read_all_years(years, directory, variables_to_look_for, variables_to_look_for_pre_2002):
    frames = []
    for i in range(len(years)):
        yr = years[i]
        print('reading files for survey year: ' + str(yr))
        temp_df = sas_read_year(directory, variables_to_look_for, yr, variables_to_look_for_pre_2002)
        temp_df = temp_df.reset_index(drop=True)  # Ensure unique index values
        frames.append(temp_df)
        if yr == 1992:
            temp_df = temp_dftgfhfghfghfghfghfghjimport rtoirmtrdex(drop=True) #1992 may have a duplicate problem
        print('\n')
    return frames
    final_frame = pd.concat(frames, ignore_index=True).drop_duplicates().reset_index(drop=True)
    return final_frame

# %%
var_dict = {
      1992: ''
    , 1994: ''
    , 1996: ''
    , 1998: ''
    , 2000: ''
    , 2002: 'h'
    , 2004: 'j' # they skip i for some reason
    , 2006: 'k'
    , 2008: 'l'
    , 2010: 'm'
    , 2012: 'n'
    , 2014: 'o'
    , 2016: 'p' 
    , 2018: 'q'
    , 2020: 'r'
}

def sas_read_year(directory, variables_to_look_for, survey_year, variables_to_look_for_pre_2002):
    # HRS and CAMS assignment
    id_variables = ['hhid', 'pn']
    
    # HRS assignments
    if survey_year < 2001:
        variables_to_look_for = variables_to_look_for_pre_2002  
    # get directories given year and survey type
    directory_sas = directory + 'h' + str(survey_year)[2:4] + 'sas'
    directory_da = directory + 'h' + str(survey_year)[2:4] + 'da'
    # get survey specific variables
    if variables_to_look_for_pre_2002 != 'CAMS':
        survey_specific_variables = [var_dict[survey_year] + x for x in variables_to_look_for]

    # CAMS assignments
    if variables_to_look_for_pre_2002 == 'CAMS':
        # survey specific variables
        survey_specific_variables = [x + '_' + str(survey_year)[2:4] for x in variables_to_look_for]
        # CAMS directories
        # 2001 has a different directory name
        if survey_year == 2001:
            ext = 'cams' + str(survey_year)[2:4]
            ext_da = ext
        # 2009 has a different directory structure
        elif survey_year == 2009:
            ext = 'cams' + str(survey_year) + '/sas'
            ext_da = 'cams' + str(survey_year) + '/data'
        else:
            ext = 'cams' + str(survey_year)
            ext_da = ext
        directory_sas = directory + ext
        directory_da = directory + ext_da

    # get list of paths: pre 1996 and some cams dont have R in them
    if survey_year < 1996:
        path_list = sorted(list(set([directory_sas + '/' +  x.split('.')[0] 
                                for x in os.listdir(directory_sas) 
                                    if 'sas' in x.lower()])))
    else:
        path_list = sorted(list(set([directory_sas + '/' +  x.split('.')[0] 
                                for x in os.listdir(directory_sas) 
                                    if ('sas' in x.lower())
                                    and (
                                          ('r' in x[len(x.split('.')[0])-1].lower()) #respondent
                                        | ('h' in x[len(x.split('.')[0])-1].lower()) #household
                                        )
                                     
                            ]
                           )
                       )
                  )
        
    # from paths, get paths leading to files which have our desired variables
    # earlier than 2000, need to read all surveys because naming conventions and variables are unrelated
    # after 2000, only reads files with desired variables in them to save a lot of time
    path_short_list = path_list
    #print(path_short_list)
    '''
    if (survey_year > 2000) and (variables_to_look_for_pre_2002 != 'CAMS'):
        surveys = [x[0] for x in variables_to_look_for] + [x[0:2] for x in variables_to_look_for if 'lb' in x]
        path_short_list = [x for x in path_list if (('r' in x.split('/')[len(x.split('/'))-1].lower()  # get respondent
                                                        and any(y == x.split('/')[len(x.split('/'))-1].lower()[3:len(x.split('/')[len(x.split('/'))-1]) - 2] 
                                                                    for y in surveys) # get specific file
                                                    )  
                                                   ) 
                            or (('h' in x.split('/')[len(x.split('/'))-1].lower())  # get household
                                # take all surveys we are looking for, only keep if HH survey (this is the last list comprehension below)
                                and any(y == x.split('/')[len(x.split('/'))-1].lower()[3:len(x.split('/')[len(x.split('/'))-1]) - 2] 
                                                                    for y in [w for w in surveys if w in ['h', 'q', 'r', 'u']])
                                )
                           ]
    #
    (path_short_list)
    '''
    # rename variables to names chosen in input dictionary
    rename_dict = copy.deepcopy(variables_to_look_for)
    vars_list = [x for x in variables_to_look_for]
    for x in range(len(survey_specific_variables)):
        rename_dict[survey_specific_variables[x].upper()] = rename_dict.pop(vars_list[x])  
    print('looking for variables: ' + str(survey_specific_variables))
    
    # get proper file extensions
    # this maybe can get coded away if handle all the info in path and path short list better
    for i in range(len(path_short_list)):
        path = path_short_list[i]
        path_ind = len(path.split('/')) - 1
        if survey_year < 2001:
            ext_surv_dct = '/' + path.split('/')[path_ind] +  '.SAS' #in the year 2000, files are .SAS and not .sas
            ext_surv_da = '/' + path.split('/')[path_ind] + '.DA'
        else:
            ext_surv_dct = '/' + path.split('/')[path_ind] +  '.sas'
            ext_surv_da = '/' + path.split('/')[path_ind] + '.da'
        dct_file = directory_sas + ext_surv_dct
        filename = directory_da + ext_surv_da
        print(filename)
        # read the files
        temp_df = read_sas_fwf(dct_file, filename, survey_specific_variables)
        temp_df = temp_df.rename(columns = rename_dict)
        if i == 0:
            year_frame = temp_df
        else:
            try:
                year_frame = year_frame.merge(temp_df, on = ["HHID", "PN"], how = "outer")
            except:
                try:
                    ##### MERGE HOUSEHOLD DATA ON TO RESPONDENT LEVEL, GET DATASET UNIQUE AT THE HHID LEVEL ###############
                    # Lowest number is for the first person in the dataset with that HHID, so most likely oldest, or head of household(?)
                    ### We want the lowest QPN_FIN number for each HHID
                    ### If no QPN_FIN number for a HHID, select lowest QPN_FAM
                    ### IF no QPN_FIN or QPN_FAM, we want the lowest QPN_CS number
                    #temp_df = temp_df.sort_values(['HHID', 'PN_CS', 'PN_FIN', 'PN_FAM']).reset_index(drop = True)

                    # Keep top row for each HHID
                    #temp_df = temp_df.drop_duplicates(subset=['HHID'], keep = 'first')
                    
                    # THEN MERGE ONCE ROWS ARE UNIQUE TO HHID ###########
                    year_frame = year_frame.merge(temp_df, on = ["HHID"], how = "outer") # for households
                    print('household survey')
                except:
                    print('this is a pre-1996 household survey, so exclude') # pre-1996 some surveys wont have a PN

    # make the wave variable, 1992 was wave 1
    year_frame['wave'] = (survey_year - 1990) / 2
    return year_frame

# %%
def read_sas_fwf(dct_file, filename, survey_specific_variables):
    # global id variables
    id_vars = ['hhid', 'pn']

    # parse the .sas file for relevant lines
    colons = []
    with open(dct_file) as f:
        lines = f.readlines()
    for i in range(len(lines)):
        if 'INPUT' in lines[i]:
            cols_start = i
        if 'LABEL' in lines[i]:
            names_start = i
        if ';' in lines[i]:
            colons.append(i)
    cols_end = [x for x in colons if x > cols_start and x < names_start][0]
    names_end = [x for x in colons if x > names_start][0]
    dictionary = lines[cols_start + 1: cols_end]
    
    # parse the relevant lines into outputs necessary for pd.read_fwf
    colspecs = []
    type_dict = {}
    names = []
    
    # can maybe make this faster by using pandas functions. unnecessary though
    for i in dictionary:
        
        # these comprehensions standardize the differences in sas files over the years
        temp = i.lstrip().split(' ')
        temp = [x.replace('\n', '').split('-') for x in temp]
        temp = [item for sublist in temp for item in sublist] # flatten the list
        temp = [i for i in temp if i]                         # removes empty strings
        
        # only read a variable if it matches survey specific variables
        if any([temp[0].lower() == y for y in id_vars + survey_specific_variables]):
            names.append(temp[0])
            if temp[1] == '$':
                var = str
                colspecs.append([int(temp[2]) - 1, int(temp[3])])
            else:
                var = float
                colspecs.append([int(temp[1]) - 1, int(temp[2])])
            type_dict[temp[0]] = var         
    return pd.read_fwf(filename, colspecs=colspecs, names = names, converters = type_dict)

# %%
cwd = os.getcwd()
directory = cwd + '/data/HRS/'
#years = [2002]
years = [2002, 2004, 2006, 2008, 2010, 2012, 2014, 2016
        ]
output = read_all_years(years, directory, variables_to_look_for, variables_to_look_for_pre_2002)
# Out:
# reading files for survey year: 2002
# looking for variables: ['ha500', 'ha501', 'hx026m', 'hx060_r', 'hx067_r', 'ha019', 'ha028', 'ha066', 'ha068m', 'hb002', 'hb005m', 'hb003m', 'hb014', 'hb017m', 'hb028', 'hb031a', 'hq020', 'hb033', 'hb050', 'hmarital', 'hb058', 'hc115', 'hc001', 'hc002', 'hc003', 'hc004', 'hc005', 'hc009', 'hc010', 'hc016', 'hc018', 'hc023', 'hc030', 'hc031', 'hc036', 'hc039', 'hc053', 'hc055', 'hc065', 'hc066', 'hc070', 'hc071', 'hc104', 'hc105', 'hc116', 'hc117', 'hc128', 'hc129', 'hc130', 'hc144', 'hc148', 'hc149', 'hc150', 'hc154', 'hc155', 'hc156', 'hd101', 'hd110', 'he012', 'he118', 'he119', 'hh002', 'hh004', 'hh020', 'hh070', 'hj005m1', 'hj018', 'hp004', 'hp007', 'hq481', 'h005', 'h034', 'h035', 'h037', 'h038', 'h040', 'h041']
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h02da/H02A_H.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h02da/H02A_R.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h02da/H02B_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h02da/H02C_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h02da/H02D_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h02da/H02E_H.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h02da/H02F_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h02da/H02G_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h02da/H02H_H.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h02da/H02IO_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h02da/H02J_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h02da/H02K_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h02da/H02L_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h02da/H02M1_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h02da/H02M2_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h02da/H02N_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h02da/H02PR_H.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h02da/H02PR_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h02da/H02P_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h02da/H02Q_H.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h02da/H02RC_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h02da/H02R_H.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h02da/H02S_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h02da/H02T_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h02da/H02V_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h02da/H02W_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h02da/H02Y_R.da
#
#
# reading files for survey year: 2004
# looking for variables: ['ja500', 'ja501', 'jx026m', 'jx060_r', 'jx067_r', 'ja019', 'ja028', 'ja066', 'ja068m', 'jb002', 'jb005m', 'jb003m', 'jb014', 'jb017m', 'jb028', 'jb031a', 'jq020', 'jb033', 'jb050', 'jmarital', 'jb058', 'jc115', 'jc001', 'jc002', 'jc003', 'jc004', 'jc005', 'jc009', 'jc010', 'jc016', 'jc018', 'jc023', 'jc030', 'jc031', 'jc036', 'jc039', 'jc053', 'jc055', 'jc065', 'jc066', 'jc070', 'jc071', 'jc104', 'jc105', 'jc116', 'jc117', 'jc128', 'jc129', 'jc130', 'jc144', 'jc148', 'jc149', 'jc150', 'jc154', 'jc155', 'jc156', 'jd101', 'jd110', 'je012', 'je118', 'je119', 'jh002', 'jh004', 'jh020', 'jh070', 'jj005m1', 'jj018', 'jp004', 'jp007', 'jq481', 'j005', 'j034', 'j035', 'j037', 'j038', 'j040', 'j041']
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h04da/H04A_H.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h04da/H04A_R.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h04da/H04B_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h04da/H04C_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h04da/H04D_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h04da/H04E_H.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h04da/H04F_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h04da/H04G_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h04da/H04H_H.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h04da/H04IO_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h04da/H04I_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h04da/H04J_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h04da/H04K_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h04da/H04LB_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h04da/H04L_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h04da/H04M1_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h04da/H04M2_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h04da/H04N_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h04da/H04PR_H.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h04da/H04PR_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h04da/H04P_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h04da/H04Q_H.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h04da/H04RC_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h04da/H04R_H.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h04da/H04S_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h04da/H04T_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h04da/H04U_H.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h04da/H04V_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h04da/H04W_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h04da/H04Y_R.da
#
#
# reading files for survey year: 2006
# looking for variables: ['ka500', 'ka501', 'kx026m', 'kx060_r', 'kx067_r', 'ka019', 'ka028', 'ka066', 'ka068m', 'kb002', 'kb005m', 'kb003m', 'kb014', 'kb017m', 'kb028', 'kb031a', 'kq020', 'kb033', 'kb050', 'kmarital', 'kb058', 'kc115', 'kc001', 'kc002', 'kc003', 'kc004', 'kc005', 'kc009', 'kc010', 'kc016', 'kc018', 'kc023', 'kc030', 'kc031', 'kc036', 'kc039', 'kc053', 'kc055', 'kc065', 'kc066', 'kc070', 'kc071', 'kc104', 'kc105', 'kc116', 'kc117', 'kc128', 'kc129', 'kc130', 'kc144', 'kc148', 'kc149', 'kc150', 'kc154', 'kc155', 'kc156', 'kd101', 'kd110', 'ke012', 'ke118', 'ke119', 'kh002', 'kh004', 'kh020', 'kh070', 'kj005m1', 'kj018', 'kp004', 'kp007', 'kq481', 'k005', 'k034', 'k035', 'k037', 'k038', 'k040', 'k041']
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h06da/H06A_H.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h06da/H06A_R.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h06da/H06B_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h06da/H06C_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h06da/H06D_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h06da/H06E_H.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h06da/H06F_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h06da/H06G_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h06da/H06H_H.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h06da/H06IO_H.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h06da/H06IO_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h06da/H06I_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h06da/H06J_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h06da/H06K_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h06da/H06LB_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h06da/H06L_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h06da/H06M0_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h06da/H06M1_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h06da/H06M2_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h06da/H06N_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h06da/H06PR_H.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h06da/H06PR_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h06da/H06P_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h06da/H06Q_H.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h06da/H06RC_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h06da/H06R_H.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h06da/H06S_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h06da/H06TN_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h06da/H06T_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h06da/H06U_H.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h06da/H06V_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h06da/H06W_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h06da/H06Y_R.da
#
#
# reading files for survey year: 2008
# looking for variables: ['la500', 'la501', 'lx026m', 'lx060_r', 'lx067_r', 'la019', 'la028', 'la066', 'la068m', 'lb002', 'lb005m', 'lb003m', 'lb014', 'lb017m', 'lb028', 'lb031a', 'lq020', 'lb033', 'lb050', 'lmarital', 'lb058', 'lc115', 'lc001', 'lc002', 'lc003', 'lc004', 'lc005', 'lc009', 'lc010', 'lc016', 'lc018', 'lc023', 'lc030', 'lc031', 'lc036', 'lc039', 'lc053', 'lc055', 'lc065', 'lc066', 'lc070', 'lc071', 'lc104', 'lc105', 'lc116', 'lc117', 'lc128', 'lc129', 'lc130', 'lc144', 'lc148', 'lc149', 'lc150', 'lc154', 'lc155', 'lc156', 'ld101', 'ld110', 'le012', 'le118', 'le119', 'lh002', 'lh004', 'lh020', 'lh070', 'lj005m1', 'lj018', 'lp004', 'lp007', 'lq481', 'l005', 'l034', 'l035', 'l037', 'l038', 'l040', 'l041']
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h08da/H08A_H.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h08da/H08A_R.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h08da/H08B_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h08da/H08C_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h08da/H08D_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h08da/H08E_H.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h08da/H08F_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h08da/H08G_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h08da/H08H_H.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h08da/H08IO_H.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h08da/H08IO_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h08da/H08I_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h08da/H08J_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h08da/H08K_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h08da/H08LB_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h08da/H08L_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h08da/H08M1_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h08da/H08M2_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h08da/H08N_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h08da/H08PR_H.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h08da/H08PR_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h08da/H08P_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h08da/H08Q_H.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h08da/H08RC_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h08da/H08R_H.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h08da/H08S_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h08da/H08TN_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h08da/H08T_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h08da/H08U_H.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h08da/H08V_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h08da/H08W_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h08da/H08Y_R.da
#
#
# reading files for survey year: 2010
# looking for variables: ['ma500', 'ma501', 'mx026m', 'mx060_r', 'mx067_r', 'ma019', 'ma028', 'ma066', 'ma068m', 'mb002', 'mb005m', 'mb003m', 'mb014', 'mb017m', 'mb028', 'mb031a', 'mq020', 'mb033', 'mb050', 'mmarital', 'mb058', 'mc115', 'mc001', 'mc002', 'mc003', 'mc004', 'mc005', 'mc009', 'mc010', 'mc016', 'mc018', 'mc023', 'mc030', 'mc031', 'mc036', 'mc039', 'mc053', 'mc055', 'mc065', 'mc066', 'mc070', 'mc071', 'mc104', 'mc105', 'mc116', 'mc117', 'mc128', 'mc129', 'mc130', 'mc144', 'mc148', 'mc149', 'mc150', 'mc154', 'mc155', 'mc156', 'md101', 'md110', 'me012', 'me118', 'me119', 'mh002', 'mh004', 'mh020', 'mh070', 'mj005m1', 'mj018', 'mp004', 'mp007', 'mq481', 'm005', 'm034', 'm035', 'm037', 'm038', 'm040', 'm041']
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h10da/H10A_H.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h10da/H10A_R.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h10da/H10B_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h10da/H10C_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h10da/H10D_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h10da/H10E_H.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h10da/H10F_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h10da/H10G_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h10da/H10H_H.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h10da/H10IO_H.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h10da/H10IO_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h10da/H10I_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h10da/H10J_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h10da/H10K_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h10da/H10LB_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h10da/H10L_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h10da/H10M1_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h10da/H10M2_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h10da/H10N_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h10da/H10PR_H.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h10da/H10PR_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h10da/H10P_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h10da/H10Q_H.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h10da/H10RC_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h10da/H10R_H.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h10da/H10S_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h10da/H10TN_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h10da/H10T_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h10da/H10U_H.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h10da/H10V_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h10da/H10W_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h10da/H10Y_R.da
#
#
# reading files for survey year: 2012
# looking for variables: ['na500', 'na501', 'nx026m', 'nx060_r', 'nx067_r', 'na019', 'na028', 'na066', 'na068m', 'nb002', 'nb005m', 'nb003m', 'nb014', 'nb017m', 'nb028', 'nb031a', 'nq020', 'nb033', 'nb050', 'nmarital', 'nb058', 'nc115', 'nc001', 'nc002', 'nc003', 'nc004', 'nc005', 'nc009', 'nc010', 'nc016', 'nc018', 'nc023', 'nc030', 'nc031', 'nc036', 'nc039', 'nc053', 'nc055', 'nc065', 'nc066', 'nc070', 'nc071', 'nc104', 'nc105', 'nc116', 'nc117', 'nc128', 'nc129', 'nc130', 'nc144', 'nc148', 'nc149', 'nc150', 'nc154', 'nc155', 'nc156', 'nd101', 'nd110', 'ne012', 'ne118', 'ne119', 'nh002', 'nh004', 'nh020', 'nh070', 'nj005m1', 'nj018', 'np004', 'np007', 'nq481', 'n005', 'n034', 'n035', 'n037', 'n038', 'n040', 'n041']
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h12da/H12A_H.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h12da/H12A_R.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h12da/H12B_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h12da/H12C_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h12da/H12D_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h12da/H12E_H.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h12da/H12F_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h12da/H12G_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h12da/H12H_H.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h12da/H12IO_H.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h12da/H12IO_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h12da/H12I_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h12da/H12J_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h12da/H12K_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h12da/H12LB_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h12da/H12L_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h12da/H12M1_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h12da/H12M2_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h12da/H12N_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h12da/H12PR_H.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h12da/H12PR_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h12da/H12P_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h12da/H12Q_H.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h12da/H12RC_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h12da/H12R_H.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h12da/H12S_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h12da/H12TN_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h12da/H12T_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h12da/H12U_H.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h12da/H12V_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h12da/H12W_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h12da/H12Y_R.da
#
#
# reading files for survey year: 2014
# looking for variables: ['oa500', 'oa501', 'ox026m', 'ox060_r', 'ox067_r', 'oa019', 'oa028', 'oa066', 'oa068m', 'ob002', 'ob005m', 'ob003m', 'ob014', 'ob017m', 'ob028', 'ob031a', 'oq020', 'ob033', 'ob050', 'omarital', 'ob058', 'oc115', 'oc001', 'oc002', 'oc003', 'oc004', 'oc005', 'oc009', 'oc010', 'oc016', 'oc018', 'oc023', 'oc030', 'oc031', 'oc036', 'oc039', 'oc053', 'oc055', 'oc065', 'oc066', 'oc070', 'oc071', 'oc104', 'oc105', 'oc116', 'oc117', 'oc128', 'oc129', 'oc130', 'oc144', 'oc148', 'oc149', 'oc150', 'oc154', 'oc155', 'oc156', 'od101', 'od110', 'oe012', 'oe118', 'oe119', 'oh002', 'oh004', 'oh020', 'oh070', 'oj005m1', 'oj018', 'op004', 'op007', 'oq481', 'o005', 'o034', 'o035', 'o037', 'o038', 'o040', 'o041']
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h14da/H14A_H.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h14da/H14A_R.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h14da/H14B_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h14da/H14C_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h14da/H14D_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h14da/H14E_H.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h14da/H14F_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h14da/H14G_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h14da/H14H_H.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h14da/H14IO_H.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h14da/H14IO_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h14da/H14I_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h14da/H14J_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h14da/H14K_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h14da/H14LB_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h14da/H14L_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h14da/H14M1_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h14da/H14M2_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h14da/H14N_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h14da/H14PR_H.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h14da/H14PR_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h14da/H14P_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h14da/H14Q_H.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h14da/H14RC_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h14da/H14R_H.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h14da/H14S_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h14da/H14TN_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h14da/H14T_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h14da/H14U_H.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h14da/H14V_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h14da/H14W_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h14da/H14Y_R.da
#
#
# reading files for survey year: 2016
# looking for variables: ['pa500', 'pa501', 'px026m', 'px060_r', 'px067_r', 'pa019', 'pa028', 'pa066', 'pa068m', 'pb002', 'pb005m', 'pb003m', 'pb014', 'pb017m', 'pb028', 'pb031a', 'pq020', 'pb033', 'pb050', 'pmarital', 'pb058', 'pc115', 'pc001', 'pc002', 'pc003', 'pc004', 'pc005', 'pc009', 'pc010', 'pc016', 'pc018', 'pc023', 'pc030', 'pc031', 'pc036', 'pc039', 'pc053', 'pc055', 'pc065', 'pc066', 'pc070', 'pc071', 'pc104', 'pc105', 'pc116', 'pc117', 'pc128', 'pc129', 'pc130', 'pc144', 'pc148', 'pc149', 'pc150', 'pc154', 'pc155', 'pc156', 'pd101', 'pd110', 'pe012', 'pe118', 'pe119', 'ph002', 'ph004', 'ph020', 'ph070', 'pj005m1', 'pj018', 'pp004', 'pp007', 'pq481', 'p005', 'p034', 'p035', 'p037', 'p038', 'p040', 'p041']
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h16da/H16A_H.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h16da/H16A_R.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h16da/H16B_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h16da/H16C_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h16da/H16D_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h16da/H16E_H.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h16da/H16F_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h16da/H16G_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h16da/H16H_H.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h16da/H16IO_H.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h16da/H16IO_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h16da/H16I_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h16da/H16J3_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h16da/H16J_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h16da/H16LB_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h16da/H16M1_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h16da/H16M2_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h16da/H16N_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h16da/H16PR_H.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h16da/H16PR_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h16da/H16P_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h16da/H16Q_H.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h16da/H16R_H.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h16da/H16S_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h16da/H16TN_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h16da/H16T_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h16da/H16U_H.da
# household survey
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h16da/H16V_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h16da/H16W_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS/h16da/H16Y_R.da

# %%
year = 2002
for x in output:
    filename = 'hrs_data_' + str(year) + '.pkl'
    x.to_pickle(filename)
    year += 2

# %%
test_df = pd.read_pickle('hrs_data_2002.pkl')

# %%
test_df
# Out:
#          HHID   PN  rmonth_survey  ryear_survey   age  live_nursing_facility  \
# 0      000003  010            4.0        2002.0  66.0                    5.0
# 1      000003  020            4.0        2002.0  63.0                    5.0
# 2      010001  010            4.0        2002.0  62.0                    5.0
# 3      010003  030            8.0        2002.0  46.0                    5.0
# 4      010004  010            4.0        2002.0  62.0                    5.0
# ...       ...  ...            ...           ...   ...                    ...
# 97073  213468  010            9.0        2002.0  77.0                    5.0
# 97074  213471  010            6.0        2002.0  71.0                    5.0
# 97075  213475  010            7.0        2002.0  77.0                    5.0
# 97076  213479  010            6.0        2002.0  75.0                    5.0
# 97077  213479  020            6.0        2002.0  75.0                    5.0
#
#       state_nursing_facility year_born_x born_us state_born country_born  \
# 0                        NaN         NaN     NaN        NaN          NaN
# 1                        NaN         NaN     NaN        NaN          NaN
# 2                        NaN         NaN     NaN        NaN          NaN
# 3                        NaN         NaN     NaN        NaN          NaN
# 4                        NaN         NaN     NaN        NaN          NaN
# ...                      ...         ...     ...        ...          ...
# 97073                    NaN         NaN     NaN        NaN          NaN
# 97074                    NaN         NaN     NaN        NaN          NaN
# 97075                    NaN         NaN     NaN        NaN          NaN
# 97076                    NaN         NaN     NaN        NaN          NaN
# 97077                    NaN         NaN     NaN        NaN          NaN
#
#       education highest_degree race_latino_hispanic race num_children  \
# 0           NaN            NaN                  NaN  1.0          NaN
# 1           NaN            NaN                  NaN  1.0          NaN
# 2           NaN            NaN                  NaN  1.0          NaN
# 3           NaN            NaN                  NaN  1.0          NaN
# 4           NaN            NaN                  NaN  1.0          NaN
# ...         ...            ...                  ...  ...          ...
# 97073       NaN            NaN                  NaN  1.0          NaN
# 97074       NaN            NaN                  NaN  1.0          NaN
# 97075       NaN            NaN                  NaN  2.0          NaN
# 97076       NaN            NaN                  NaN  1.0          NaN
# 97077       NaN            NaN                  NaN  1.0          NaN
#
#       religion divorce_widow_status marital_status  health_status  \
# 0          NaN                  NaN            1.0            3.0
# 1          NaN                  NaN            1.0            3.0
# 2          NaN                  5.0            6.0            2.0
# 3          NaN                  5.0            5.0            1.0
# 4          NaN                  NaN            1.0            2.0
# ...        ...                  ...            ...            ...
# 97073      NaN                  5.0            5.0            5.0
# 97074      NaN                  5.0            5.0            2.0
# 97075      NaN                  5.0            4.0            2.0
# 97076      NaN                  NaN            1.0            5.0
# 97077      NaN                  NaN            1.0            3.0
#
#       health_status_compared_to_prev  \
# 0                                2.0
# 1                                1.0
# 2                                2.0
# 3                                1.0
# 4                                3.0
# ...                              ...
# 97073                            2.0
# 97074                            2.0
# 97075                            1.0
# 97076                            3.0
# 97077                            3.0
#
#       health_status_better_compared_to_prev_degree  \
# 0                                              NaN
# 1                                              2.0
# 2                                              NaN
# 3                                              1.0
# 4                                              NaN
# ...                                            ...
# 97073                                          NaN
# 97074                                          NaN
# 97075                                          1.0
# 97076                                          NaN
# 97077                                          NaN
#
#       health_status_worse_compared_to_prev_degree  high_blood_pressure  \
# 0                                             NaN                  5.0
# 1                                             NaN                  5.0
# 2                                             NaN                  5.0
# 3                                             NaN                  1.0
# 4                                             4.0                  1.0
# ...                                           ...                  ...
# 97073                                         NaN                  1.0
# 97074                                         NaN                  5.0
# 97075                                         NaN                  1.0
# 97076                                         4.0                  1.0
# 97077                                         4.0                  1.0
#
#       high_blood_pressure_compared_to_prev  diabetes  \
# 0                                      NaN       5.0
# 1                                      NaN       5.0
# 2                                      NaN       5.0
# 3                                      3.0       5.0
# 4                                      2.0       5.0
# ...                                    ...       ...
# 97073                                  2.0       5.0
# 97074                                  NaN       5.0
# 97075                                  2.0       5.0
# 97076                                  2.0       5.0
# 97077                                  2.0       5.0
#
#       diabetes_compared_to_prev  cancer cancer_compared_to_prev  lung_disease  \
# 0                           NaN     5.0                     NaN           5.0
# 1                           NaN     1.0                     NaN           5.0
# 2                           NaN     5.0                     NaN           5.0
# 3                           NaN     5.0                     NaN           1.0
# 4                           NaN     1.0                     1.0           5.0
# ...                         ...     ...                     ...           ...
# 97073                       NaN     5.0                     NaN           5.0
# 97074                       NaN     5.0                     NaN           5.0
# 97075                       NaN     5.0                     NaN           5.0
# 97076                       NaN     5.0                     NaN           5.0
# 97077                       NaN     5.0                     NaN           5.0
#
#       lung_disease_compared_to_prev  heart_condition  \
# 0                               NaN              1.0
# 1                               NaN              5.0
# 2                               NaN              5.0
# 3                               1.0              1.0
# 4                               NaN              5.0
# ...                             ...              ...
# 97073                           NaN              5.0
# 97074                           NaN              5.0
# 97075                           NaN              1.0
# 97076                           NaN              1.0
# 97077                           NaN              1.0
#
#       heart_condition_compared_to_prev  stroke  \
# 0                                  2.0     5.0
# 1                                  NaN     5.0
# 2                                  NaN     5.0
# 3                                  NaN     1.0
# 4                                  NaN     5.0
# ...                                ...     ...
# 97073                              NaN     5.0
# 97074                              NaN     5.0
# 97075                              1.0     1.0
# 97076                              2.0     5.0
# 97077                              NaN     5.0
#
#       heart_condition_compared_to_prev  psychiatric_emotional_problem  \
# 0                                  NaN                            5.0
# 1                                  NaN                            1.0
# 2                                  NaN                            1.0
# 3                                  5.0                            1.0
# 4                                  NaN                            5.0
# ...                                ...                            ...
# 97073                              NaN                            5.0
# 97074                              NaN                            5.0
# 97075                              5.0                            5.0
# 97076                              NaN                            5.0
# 97077                              NaN                            5.0
#
#       psychiatric_emotional_problem_compared_to_prev  arthritis  \
# 0                                                NaN        5.0
# 1                                                NaN        1.0
# 2                                                1.0        5.0
# 3                                                2.0        5.0
# 4                                                NaN        1.0
# ...                                              ...        ...
# 97073                                            NaN        1.0
# 97074                                            NaN        5.0
# 97075                                            NaN        1.0
# 97076                                            NaN        1.0
# 97077                                            NaN        1.0
#
#       arthritis_compared_to_prev  pain pain_degree  exercise smoke  \
# 0                            NaN   5.0         NaN       1.0   NaN
# 1                            2.0   1.0         1.0       5.0   NaN
# 2                            NaN   5.0         NaN       1.0   NaN
# 3                            NaN   5.0         NaN       5.0   NaN
# 4                            3.0   1.0         2.0       1.0   NaN
# ...                          ...   ...         ...       ...   ...
# 97073                        3.0   1.0         3.0       5.0   NaN
# 97074                        NaN   5.0         NaN       5.0   NaN
# 97075                        2.0   5.0         NaN       1.0   NaN
# 97076                        3.0   1.0         3.0       5.0   NaN
# 97077                        3.0   1.0         2.0       1.0   NaN
#
#       still_smoke  alcohol num_drinks_days_per_week num_drinks_per_day  \
# 0             5.0      1.0                      0.0                NaN
# 1             5.0      5.0                      NaN                NaN
# 2             5.0      5.0                      NaN                NaN
# 3             5.0      5.0                      NaN                NaN
# 4             5.0      1.0                      3.0                3.0
# ...           ...      ...                      ...                ...
# 97073         5.0      5.0                      NaN                NaN
# 97074         5.0      5.0                      NaN                NaN
# 97075         5.0      5.0                      NaN                NaN
# 97076         1.0      1.0                      7.0                1.0
# 97077         5.0      1.0                      7.0                1.0
#
#       shortness_breath fatigue cough depressed_x tired appetite_loss  \
# 0                  NaN     NaN   NaN         NaN   NaN           NaN
# 1                  NaN     NaN   NaN         NaN   NaN           NaN
# 2                  NaN     NaN   NaN         NaN   NaN           NaN
# 3                  NaN     NaN   NaN         NaN   NaN           NaN
# 4                  NaN     NaN   NaN         NaN   NaN           NaN
# ...                ...     ...   ...         ...   ...           ...
# 97073              NaN     NaN   NaN         NaN   NaN           NaN
# 97074              NaN     NaN   NaN         NaN   NaN           NaN
# 97075              NaN     NaN   NaN         NaN   NaN           NaN
# 97076              NaN     NaN   NaN         NaN   NaN           NaN
# 97077              NaN     NaN   NaN         NaN   NaN           NaN
#
#       appetite_increase memory_x depressed_y children_nearby dependents  \
# 0                   NaN      3.0         5.0             5.0        5.0
# 1                   NaN      3.0         5.0             5.0        5.0
# 2                   NaN      3.0         5.0             NaN        NaN
# 3                   NaN      5.0         5.0             NaN        5.0
# 4                   NaN      3.0         1.0             1.0        5.0
# ...                 ...      ...         ...             ...        ...
# 97073               NaN      NaN         NaN             1.0        5.0
# 97074               NaN      3.0         5.0             1.0        5.0
# 97075               NaN      3.0         5.0             5.0        5.0
# 97076               NaN      3.0         5.0             1.0        5.0
# 97077               NaN      3.0         5.0             1.0        5.0
#
#       num_dependents type_house own_or_rent property_value  \
# 0                NaN        2.0         1.0       150000.0
# 1                NaN        2.0         1.0       150000.0
# 2                NaN        4.0         1.0       450000.0
# 3                NaN        4.0         1.0        10000.0
# 4                NaN        2.0         1.0       200000.0
# ...              ...        ...         ...            ...
# 97073            NaN        2.0         7.0            NaN
# 97074            NaN        2.0         1.0       165000.0
# 97075            NaN        2.0         1.0       100000.0
# 97076            NaN        2.0         1.0       150000.0
# 97077            NaN        2.0         1.0       150000.0
#
#       year_property_acquired vocab_level friendliness attentiveness  \
# 0                        NaN         2.0          3.0           3.0
# 1                        NaN         2.0          3.0           3.0
# 2                        NaN         3.0          3.0           3.0
# 3                        NaN         1.0          3.0           3.0
# 4                     1987.0         8.0          8.0           8.0
# ...                      ...         ...          ...           ...
# 97073                    NaN         2.0          3.0           3.0
# 97074                    NaN         2.0          3.0           3.0
# 97075                    NaN         3.0          3.0           3.0
# 97076                    NaN         2.0          3.0           2.0
# 97077                    NaN         2.0          3.0           3.0
#
#       cooperation tiredness memory_y hearing employment_status year_retired  \
# 0             1.0       2.0      3.0     1.0               1.0          NaN
# 1             1.0       3.0      1.0     1.0               3.0          NaN
# 2             1.0       3.0      1.0     1.0               5.0       1998.0
# 3             1.0       3.0      1.0     1.0               4.0          NaN
# 4             8.0       8.0      8.0     8.0               4.0          NaN
# ...           ...       ...      ...     ...               ...          ...
# 97073         1.0       3.0      1.0     1.0               6.0          NaN
# 97074         2.0       3.0      1.0     1.0               1.0          NaN
# 97075         1.0       3.0      2.0     1.0               5.0          NaN
# 97076         2.0       1.0      1.0     4.0               1.0          NaN
# 97077         1.0       2.0      1.0     1.0               6.0          NaN
#
#       state_live  gender  year_born_y financial_expectation leave_inheritance  \
# 0            9.0     1.0       1936.0                  20.0               NaN
# 1            9.0     2.0       1938.0                  80.0               NaN
# 2            2.0     1.0       1939.0                  50.0               0.0
# 3            2.0     2.0       1956.0                   0.0               NaN
# 4            2.0     1.0       1939.0                  70.0               NaN
# ...          ...     ...          ...                   ...               ...
# 97073        5.0     2.0       1925.0                   NaN               NaN
# 97074        5.0     2.0       1930.0                 998.0               NaN
# 97075        5.0     2.0       1925.0                  75.0               NaN
# 97076        5.0     1.0       1927.0                  50.0               NaN
# 97077        5.0     2.0       1926.0                  60.0               NaN
#
#         income debt_amount  wave
# 0      10000.0         NaN   6.0
# 1      10000.0         NaN   6.0
# 2          NaN         NaN   6.0
# 3          NaN         NaN   6.0
# 4          NaN         NaN   6.0
# ...        ...         ...   ...
# 97073      NaN         NaN   6.0
# 97074      NaN        98.0   6.0
# 97075      NaN         NaN   6.0
# 97076      NaN         NaN   6.0
# 97077      NaN         NaN   6.0
#
# [97078 rows x 80 columns]

# %%
test_df2 = pd.read_pickle('hrs_data_2012.pkl')

# %%
test_df2[test_df2['HHID'] == "000003"]
# Out:
#      HHID   PN  rmonth_survey  ryear_survey   age  live_nursing_facility  \
# 0  000003  010            7.0        2012.0  76.0                    5.0
# 1  000003  020            7.0        2012.0  73.0                    5.0
#
#   state_nursing_facility year_born_x born_us state_born education  \
# 0                    NaN         NaN     NaN        NaN       NaN
# 1                    NaN         NaN     NaN        NaN       NaN
#
#   highest_degree race_latino_hispanic num_children religion  \
# 0            NaN                  NaN          NaN      NaN
# 1            NaN                  NaN          NaN      NaN
#
#   divorce_widow_status health_status health_status_compared_to_prev  \
# 0                  NaN           3.0                            3.0
# 1                  NaN           4.0                            3.0
#
#   high_blood_pressure high_blood_pressure_compared_to_prev diabetes  \
# 0                 5.0                                  NaN      5.0
# 1                 1.0                                  NaN      5.0
#
#   diabetes_compared_to_prev cancer cancer_compared_to_prev lung_disease  \
# 0                       NaN    5.0                     NaN          5.0
# 1                       NaN    1.0                     NaN          5.0
#
#   lung_disease_compared_to_prev heart_condition  \
# 0                           NaN             1.0
# 1                           NaN             1.0
#
#   heart_condition_compared_to_prev stroke heart_condition_compared_to_prev  \
# 0                              2.0    5.0                              NaN
# 1                              NaN    5.0                              NaN
#
#   psychiatric_emotional_problem  \
# 0                           5.0
# 1                           1.0
#
#   psychiatric_emotional_problem_compared_to_prev arthritis  \
# 0                                            NaN       5.0
# 1                                            2.0       1.0
#
#   arthritis_compared_to_prev pain pain_degree smoke still_smoke alcohol  \
# 0                        NaN  5.0         NaN   NaN         NaN     5.0
# 1                        3.0  1.0         2.0   NaN         NaN     5.0
#
#   num_drinks_days_per_week num_drinks_per_day shortness_breath fatigue cough  \
# 0                      NaN                NaN              1.0     1.0   1.0
# 1                      NaN                NaN              1.0     5.0   5.0
#
#   depressed_x tired appetite_loss appetite_increase memory_x depressed_y  \
# 0         5.0   NaN           NaN               NaN      4.0         5.0
# 1         5.0   NaN           NaN               NaN      3.0         5.0
#
#   children_nearby dependents num_dependents type_house own_or_rent  \
# 0             5.0        5.0            NaN        2.0         1.0
# 1             5.0        5.0            NaN        2.0         1.0
#
#   property_value year_property_acquired vocab_level cooperation tiredness  \
# 0       200000.0                    NaN         2.0         3.0       1.0
# 1       200000.0                    NaN         2.0         3.0       1.0
#
#   memory_y hearing employment_status year_retired state_live gender  \
# 0      NaN     NaN               5.0          NaN        9.0    1.0
# 1      NaN     NaN               5.0          NaN        9.0    2.0
#
#   year_born_y leave_inheritance income debt_amount  wave
# 0      1936.0               NaN    NaN         NaN  11.0
# 1      1938.0               NaN    NaN         NaN  11.0

# %%
output['hhidpn'] = output['HHID'] + output['PN']
output.groupby('wave').count()
# Out:
#        HHID     PN  rmonth_survey  ryear_survey    age  live_nursing_facility  \
# wave
# 6.0   22267  22267          22267         22267  22191                  22267
#
#       state_nursing_facility  year_born_x  born_us  state_born  country_born  \
# wave
# 6.0                      569          569      616         517            99
#
#       education  highest_degree  race_latino_hispanic   race  num_children  \
# wave
# 6.0         616             166                   616  22214           616
#
#       religion  divorce_widow_status  marital_status  health_status  \
# wave
# 6.0        614                  8723           22266          22267
#
#       health_status_compared_to_prev  \
# wave
# 6.0                            21651
#
#       health_status_better_compared_to_prev_degree  \
# wave
# 6.0                                           2003
#
#       health_status_worse_compared_to_prev_degree  high_blood_pressure  \
# wave
# 6.0                                          5915                22267
#
#       high_blood_pressure_compared_to_prev  diabetes  \
# wave
# 6.0                                   9398     22267
#
#       diabetes_compared_to_prev  cancer  cancer_compared_to_prev  \
# wave
# 6.0                        3072   22267                     1450
#
#       lung_disease  lung_disease_compared_to_prev  heart_condition  \
# wave
# 6.0          22267                           1609            22267
#
#       heart_condition_compared_to_prev  stroke  \
# wave
# 6.0                               3690   22267
#
#       heart_condition_compared_to_prev  psychiatric_emotional_problem  \
# wave
# 6.0                               1585                          22267
#
#       psychiatric_emotional_problem_compared_to_prev  arthritis  \
# wave
# 6.0                                             3074      22267
#
#       arthritis_compared_to_prev   pain  pain_degree  exercise  smoke  \
# wave
# 6.0                        10984  22267         6864     22267    616
#
#       still_smoke  alcohol  num_drinks_days_per_week  num_drinks_per_day  \
# wave
# 6.0         21995    22267                     10534                7029
#
#       shortness_breath  fatigue  cough  depressed_x  tired  appetite_loss  \
# wave
# 6.0                616      616    616          561     61             61
#
#       appetite_increase  memory_x  depressed_y  children_nearby  dependents  \
# wave
# 6.0                  37     19986        19986            19820       21970
#
#       num_dependents  type_house  own_or_rent  property_value  \
# wave
# 6.0             2205       21677        19656           15947
#
#       year_property_acquired  vocab_level  friendliness  attentiveness  \
# wave
# 6.0                     2744        22233         22027          22027
#
#       cooperation  tiredness  memory_y  hearing  employment_status  \
# wave
# 6.0         22027      22027     22027    22027              22253
#
#       year_retired  state_live  gender  year_born_y  financial_expectation  \
# wave
# 6.0           2550       22163   22267        22267                  19971
#
#       leave_inheritance  income  debt_amount  hhidpn
# wave
# 6.0                3346    8071          529   22267

# %% [markdown]
# ## Determine labels dictionary now (death year for each HHID PN ID)

# %%
files = [
    "hrs_data_2002.pkl",
    "hrs_data_2004.pkl",
    "hrs_data_2006.pkl",
    "hrs_data_2008.pkl",
    "hrs_data_2010.pkl",
    "hrs_data_2012.pkl",
    "hrs_data_2014.pkl",
    "hrs_data_2016.pkl",
         ]

labels_dict = {}

df_2002 = pd.read_pickle('hrs_data_2002.pkl')
df_2004 = pd.read_pickle('hrs_data_2004.pkl')
df_2006 = pd.read_pickle('hrs_data_2006.pkl')
df_2008 = pd.read_pickle('hrs_data_2008.pkl')
df_2010 = pd.read_pickle('hrs_data_2010.pkl')
df_2012 = pd.read_pickle('hrs_data_2012.pkl')
df_2014 = pd.read_pickle('hrs_data_2014.pkl')
df_2016 = pd.read_pickle('hrs_data_2016.pkl')

dataframes = {
    2002: df_2002,
    2004: df_2004,
    2006: df_2006,
    2008: df_2008,
    2010: df_2010,
    2012: df_2012,
    2014: df_2014,
    2016: df_2016
}

# %%
sets_by_year = {year: set(zip(df['HHID'], df['PN'])) for year, df in dataframes.items()}

# %%
def find_earliest_missing_year(hhid, pn, start_year, sorted_years, sets_by_year):
    """
    Finds the earliest year where the given (HHID, PN) is missing, starting from a specific year.
    """
    for year in sorted_years:
        if year > start_year and (hhid, pn) not in sets_by_year[year]:
            return year
    return 0  # Return 0 if the individual is present in all years

# %%
results = []

# Get a sorted list of all years
all_years = sorted(dataframes.keys())

# Iterate through all DataFrames
for year in all_years:
    df = dataframes[year]
    # Add a column for the earliest missing year
    df['Earliest_Missing_Year'] = df.apply(
        lambda row: find_earliest_missing_year(row['HHID'], row['PN'], year, all_years, sets_by_year),
        axis=1
    )
    # Add year information and append to results
    df['Base_Year'] = year
    results.append(df[['HHID', 'PN', 'Base_Year', 'Earliest_Missing_Year']])

# Step 4: Combine results into a single DataFrame
final_results = pd.concat(results, ignore_index=True)

# Display the results
print(final_results)
# Out:
#             HHID   PN  Base_Year  Earliest_Missing_Year
# 0         000003  010       2002                   2014
# 1         000003  020       2002                   2016
# 2         010001  010       2002                      0
# 3         010003  030       2002                      0
# 4         010004  010       2002                   2012
# ...          ...  ...        ...                    ...
# 10124328  923525  010       2016                      0
# 10124329  923525  020       2016                      0
# 10124330  952836  010       2016                      0
# 10124331  958361  010       2016                      0
# 10124332  959738  010       2016                      0
#
# [10124333 rows x 4 columns]

# %%
final_results['Earliest_Missing_Year'].value_counts()
# Out:
# Earliest_Missing_Year
# 0       6628356
# 2016    1137926
# 2014     881815
# 2010     709666
# 2008     498092
# 2012     198780
# 2006      63542
# 2004       6156
# Name: count, dtype: int64

# %%
final_results.groupby(['Earliest_Missing_Year', 'Base_Year']).size().reset_index(name='counts')
# Out:
#     Earliest_Missing_Year  Base_Year   counts
# 0                       0       2002    47722
# 1                       0       2004   186336
# 2                       0       2006  1317944
# 3                       0       2008   875899
# 4                       0       2010   859335
# 5                       0       2012  1049895
# 6                       0       2014  1046988
# 7                       0       2016  1244237
# 8                    2004       2002     6156
# 9                    2006       2002    11344
# 10                   2006       2004    52198
# 11                   2008       2002     9763
# 12                   2008       2004    36294
# 13                   2008       2006   452035
# 14                   2010       2002     5547
# 15                   2010       2004    19973
# 16                   2010       2006   500240
# 17                   2010       2008   183906
# 18                   2012       2002     5345
# 19                   2012       2004    14851
# 20                   2012       2006    45498
# 21                   2012       2008    62798
# 22                   2012       2010    70288
# 23                   2014       2002     6502
# 24                   2014       2004    50290
# 25                   2014       2006   442531
# 26                   2014       2008   150131
# 27                   2014       2010   103432
# 28                   2014       2012   128929
# 29                   2016       2002     4699
# 30                   2016       2004    30450
# 31                   2016       2006   117051
# 32                   2016       2008   142188
# 33                   2016       2010   199574
# 34                   2016       2012   309725
# 35                   2016       2014   334239

# %%
final_results.to_pickle("hrs_labels.pkl")

# %% [markdown]
# ## Trying to navigate through exit interviews

# %%
################### import packages ##########################################
import pandas as pd
import re
import numpy as np
import os
import copy 
import fnmatch
# %load_ext line_profiler
pd.set_option('display.max_columns', None)

##############################################################################
####### choose variables to look for from codebooks ###########################
##############################################################################

# make sure these are all lowercase!!! #####################

# for HRS core files, 2002 - present
#SELECT VARIABLES OF INTEREST

variables_to_look_for = { 'a500':'rmonth_survey'
                         , 'a501':'ryear_survey'
                          , 'a123':'year_death'
                         }


# for HRS core files, pre 2002
# 2000 has g's, 1998 has f's, 1996 has e's, 1994 has w's, 1992 has v's
variables_to_look_for_pre_2002 = {
      'g775': 'rmonth_survey'
    , 'f704': 'rmonth_survey'
    , 'e391': 'rmonth_survey'
    , 'w120': 'rmonth_survey'
    , 'v128': 'rmonth_survey'
    , 'g774': 'ryear_survey'
    , 'f703': 'ryear_survey'
    , 'e393': 'ryear_survey'
    , 'w122': 'ryear_survey'
    , 'v127': 'ryear_survey'
    , 'g4996': 'rpr_lose_job'
    , 'f4583': 'rpr_lose_job'
    , 'e3788': 'rpr_lose_job'
    , 'w5801': 'rpr_lose_job' 
    , 'v3205': 'rpr_lose_job'    
}

var_dict = {
      1992: ''
    , 1994: ''
    , 1996: ''
    , 1998: ''
    , 2000: ''
    , 2002: 's'
    , 2004: 'j' # they skip i for some reason
    , 2006: 'k'
    , 2008: 'l'
    , 2010: 'm'
    , 2012: 'n'
    , 2014: 'o'
    , 2016: 'p' 
    , 2018: 'q'
    , 2020: 'r'
}
# Out:
# The line_profiler extension is already loaded. To reload it, use:
#   %reload_ext line_profiler

# %%
def sas_read_year(directory, variables_to_look_for, survey_year, variables_to_look_for_pre_2002):
    # HRS and CAMS assignment
    id_variables = ['hhid', 'pn']
    
    # HRS assignments
    if survey_year < 2001:
        variables_to_look_for = variables_to_look_for_pre_2002  
    # get directories given year and survey type
    directory_sas = directory + 'x' + str(survey_year)[2:4] + 'sas'
    directory_da = directory + 'x' + str(survey_year)[2:4] + 'da'
    # get survey specific variables
    if variables_to_look_for_pre_2002 != 'CAMS':
        survey_specific_variables = [var_dict[survey_year] + x for x in variables_to_look_for]

    # CAMS assignments
    if variables_to_look_for_pre_2002 == 'CAMS':
        # survey specific variables
        survey_specific_variables = [x + '_' + str(survey_year)[2:4] for x in variables_to_look_for]
        # CAMS directories
        # 2001 has a different directory name
        if survey_year == 2001:
            ext = 'cams' + str(survey_year)[2:4]
            ext_da = ext
        # 2009 has a different directory structure
        elif survey_year == 2009:
            ext = 'cams' + str(survey_year) + '/sas'
            ext_da = 'cams' + str(survey_year) + '/data'
        else:
            ext = 'cams' + str(survey_year)
            ext_da = ext
        directory_sas = directory + ext
        directory_da = directory + ext_da

    # get list of paths: pre 1996 and some cams dont have R in them
    if survey_year < 1996:
        path_list = sorted(list(set([directory_sas + '/' +  x.split('.')[0] 
                                for x in os.listdir(directory_sas) 
                                    if 'sas' in x.lower()])))
    else:
        path_list = sorted(list(set([directory_sas + '/' +  x.split('.')[0] 
                                for x in os.listdir(directory_sas) 
                                    if ('sas' in x.lower())
                                    and (
                                          ('r' in x[len(x.split('.')[0])-1].lower()) #respondent
                                        | ('h' in x[len(x.split('.')[0])-1].lower()) #household
                                        )
                                     
                            ]
                           )
                       )
                  )
        
    # from paths, get paths leading to files which have our desired variables
    # earlier than 2000, need to read all surveys because naming conventions and variables are unrelated
    # after 2000, only reads files with desired variables in them to save a lot of time
    path_short_list = path_list
    #print(path_short_list)
    '''
    if (survey_year > 2000) and (variables_to_look_for_pre_2002 != 'CAMS'):
        surveys = [x[0] for x in variables_to_look_for] + [x[0:2] for x in variables_to_look_for if 'lb' in x]
        path_short_list = [x for x in path_list if (('r' in x.split('/')[len(x.split('/'))-1].lower()  # get respondent
                                                        and any(y == x.split('/')[len(x.split('/'))-1].lower()[3:len(x.split('/')[len(x.split('/'))-1]) - 2] 
                                                                    for y in surveys) # get specific file
                                                    )  
                                                   ) 
                            or (('h' in x.split('/')[len(x.split('/'))-1].lower())  # get household
                                # take all surveys we are looking for, only keep if HH survey (this is the last list comprehension below)
                                and any(y == x.split('/')[len(x.split('/'))-1].lower()[3:len(x.split('/')[len(x.split('/'))-1]) - 2] 
                                                                    for y in [w for w in surveys if w in ['h', 'q', 'r', 'u']])
                                )
                           ]
    #
    (path_short_list)
    '''
    # rename variables to names chosen in input dictionary
    rename_dict = copy.deepcopy(variables_to_look_for)
    vars_list = [x for x in variables_to_look_for]
    for x in range(len(survey_specific_variables)):
        rename_dict[survey_specific_variables[x].upper()] = rename_dict.pop(vars_list[x])  
    print('looking for variables: ' + str(survey_specific_variables))
    
    # get proper file extensions
    # this maybe can get coded away if handle all the info in path and path short list better
    for i in range(len(path_short_list)):
        path = path_short_list[i]
        path_ind = len(path.split('/')) - 1
        if survey_year < 2001:
            ext_surv_dct = '/' + path.split('/')[path_ind] +  '.SAS' #in the year 2000, files are .SAS and not .sas
            ext_surv_da = '/' + path.split('/')[path_ind] + '.DA'
        else:
            ext_surv_dct = '/' + path.split('/')[path_ind] +  '.sas'
            ext_surv_da = '/' + path.split('/')[path_ind] + '.da'
        dct_file = directory_sas + ext_surv_dct
        filename = directory_da + ext_surv_da
        print(filename)
        # read the files
        temp_df = read_sas_fwf(dct_file, filename, survey_specific_variables)
        temp_df = temp_df.rename(columns = rename_dict)
        if i == 0:
            year_frame = temp_df
        else:
            try:
                year_frame = year_frame.merge(temp_df, on = ["HHID", "PN"], how = "outer")
            except:
                try:
                    ##### MERGE HOUSEHOLD DATA ON TO RESPONDENT LEVEL, GET DATASET UNIQUE AT THE HHID LEVEL ###############
                    # Lowest number is for the first person in the dataset with that HHID, so most likely oldest, or head of household(?)
                    ### We want the lowest QPN_FIN number for each HHID
                    ### If no QPN_FIN number for a HHID, select lowest QPN_FAM
                    ### IF no QPN_FIN or QPN_FAM, we want the lowest QPN_CS number
                    #temp_df = temp_df.sort_values(['HHID', 'PN_CS', 'PN_FIN', 'PN_FAM']).reset_index(drop = True)

                    # Keep top row for each HHID
                    #temp_df = temp_df.drop_duplicates(subset=['HHID'], keep = 'first')
                    
                    # THEN MERGE ONCE ROWS ARE UNIQUE TO HHID ###########
                    year_frame = year_frame.merge(temp_df, on = ["HHID"], how = "outer") # for households
                    print('household survey')
                except:
                    print('this is a pre-1996 household survey, so exclude') # pre-1996 some surveys wont have a PN

    # make the wave variable, 1992 was wave 1
    year_frame['wave'] = (survey_year - 1990) / 2
    return year_frame

# %%
cwd = os.getcwd()
directory = cwd + '/data/HRS_EXIT/'
years = [2002, 2004, 2006, 2008, 2010, 2012, 2014, 2016
        ]
output = read_all_years(years, directory, variables_to_look_for, variables_to_look_for_pre_2002)
# Out:
# reading files for survey year: 2002
# looking for variables: ['sa500', 'sa501', 'sa123']
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x02da/x02A_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x02da/x02B_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x02da/x02C_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x02da/x02D_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x02da/x02E_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x02da/x02G_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x02da/x02IO_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x02da/x02J_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x02da/x02N_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x02da/x02PR_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x02da/x02T_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x02da/x02W_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x02da/x02Y_R.da
#
#
# reading files for survey year: 2004
# looking for variables: ['ja500', 'ja501', 'ja123']
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x04da/x04A_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x04da/x04B_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x04da/x04C_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x04da/x04D_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x04da/x04E_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x04da/x04G_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x04da/x04IO_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x04da/x04J_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x04da/x04N_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x04da/x04PR_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x04da/x04T_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x04da/x04W_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x04da/x04Y_R.da
#
#
# reading files for survey year: 2006
# looking for variables: ['ka500', 'ka501', 'ka123']
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x06da/X06A_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x06da/X06B_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x06da/X06C_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x06da/X06D_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x06da/X06E_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x06da/X06G_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x06da/X06IO_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x06da/X06J_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x06da/X06N_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x06da/X06PR_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x06da/X06T_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x06da/X06Y_R.da
#
#
# reading files for survey year: 2008
# looking for variables: ['la500', 'la501', 'la123']
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x08da/X08A_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x08da/X08B_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x08da/X08C_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x08da/X08D_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x08da/X08E_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x08da/X08G_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x08da/X08IO_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x08da/X08J_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x08da/X08N_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x08da/X08PR_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x08da/X08T_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x08da/X08Y_R.da
#
#
# reading files for survey year: 2010
# looking for variables: ['ma500', 'ma501', 'ma123']
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x10da/X10A_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x10da/X10B_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x10da/X10C_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x10da/X10D_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x10da/X10E_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x10da/X10G_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x10da/X10IO_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x10da/X10J_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x10da/X10N_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x10da/X10PR_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x10da/X10T_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x10da/X10Y_R.da
#
#
# reading files for survey year: 2012
# looking for variables: ['na500', 'na501', 'na123']
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x12da/X12A_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x12da/X12B_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x12da/X12C_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x12da/X12D_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x12da/X12E_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x12da/X12G_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x12da/X12IO_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x12da/X12J_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x12da/X12N_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x12da/X12PR_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x12da/X12T_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x12da/X12Y_R.da
#
#
# reading files for survey year: 2014
# looking for variables: ['oa500', 'oa501', 'oa123']
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x14da/X14A_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x14da/X14B_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x14da/X14C_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x14da/X14D_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x14da/X14E_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x14da/X14G_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x14da/X14IO_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x14da/X14J_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x14da/X14N_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x14da/X14PR_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x14da/X14T_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x14da/X14Y_R.da
#
#
# reading files for survey year: 2016
# looking for variables: ['pa500', 'pa501', 'pa123']
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x16da/X16A_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x16da/X16B_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x16da/X16C_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x16da/X16D_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x16da/X16E_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x16da/X16G_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x16da/X16IO_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x16da/X16J_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x16da/X16N_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x16da/X16PR_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x16da/X16T_R.da
# /Users/zengsimon/Desktop/NYU/Fall24/EthicalML/final_project/preprocess/data/HRS_EXIT/x16da/X16Y_R.da

# %%
final_frame = pd.concat(output, ignore_index=True).drop_duplicates().reset_index(drop=True)

# %%
final_frame
# Out:
#          HHID   PN  rmonth_survey  ryear_survey  year_death  wave
# 0      000002  010            9.0        2002.0      2001.0   6.0
# 1      010460  010           11.0        2002.0      2002.0   6.0
# 2      010468  020           11.0        2002.0      2002.0   6.0
# 3      010565  030            8.0        2002.0      2001.0   6.0
# 4      010571  020           10.0        2002.0      2000.0   6.0
# ...       ...  ...            ...           ...         ...   ...
# 10548  918882  011            NaN           NaN         NaN  13.0
# 10549  919052  020            NaN           NaN         NaN  13.0
# 10550  919613  010            NaN           NaN         NaN  13.0
# 10551  920331  010            NaN           NaN         NaN  13.0
# 10552  920396  020            NaN           NaN         NaN  13.0
#
# [10553 rows x 6 columns]

# %%
final_results.to_pickle("hrs_exits.pkl")

# %%
merged_df = df_2008.merge(final_frame[['HHID', 'PN', 'year_death']], on=['HHID', 'PN'], how='inner')

# %%
merged_df
# Out:
#            HHID   PN  rmonth_survey  ryear_survey   age  \
# 0        000003  010            2.0        2008.0  72.0
# 1        000003  020            2.0        2008.0  69.0
# 2        010001  010            9.0        2008.0  69.0
# 3        010003  030            3.0        2008.0  51.0
# 4        010004  010            3.0        2008.0  68.0
# ...         ...  ...            ...           ...   ...
# 1414917  502757  010           12.0        2008.0  58.0
# 1414918  502758  010            6.0        2008.0  56.0
# 1414919  502759  010            8.0        2008.0  59.0
# 1414920  502759  020            8.0        2008.0  59.0
# 1414921  502761  010            3.0        2008.0  54.0
#
#          live_nursing_facility state_nursing_facility year_born_x born_us  \
# 0                          5.0                    NaN         NaN     NaN
# 1                          5.0                    NaN         NaN     NaN
# 2                          5.0                    NaN         NaN     NaN
# 3                          5.0                    NaN         NaN     NaN
# 4                          5.0                    NaN         NaN     NaN
# ...                        ...                    ...         ...     ...
# 1414917                    5.0                    NaN         NaN     NaN
# 1414918                    5.0                    NaN         NaN     NaN
# 1414919                    5.0                    NaN         NaN     NaN
# 1414920                    5.0                    NaN         NaN     NaN
# 1414921                    5.0                    NaN         NaN     NaN
#
#         state_born education highest_degree race_latino_hispanic num_children  \
# 0              NaN       NaN            NaN                  NaN          NaN
# 1              NaN       NaN            NaN                  NaN          NaN
# 2              NaN       NaN            NaN                  NaN          NaN
# 3              NaN       NaN            NaN                  NaN          NaN
# 4              NaN       NaN            NaN                  NaN          NaN
# ...            ...       ...            ...                  ...          ...
# 1414917        NaN       NaN            NaN                  5.0          NaN
# 1414918        NaN       NaN            NaN                  NaN          NaN
# 1414919        NaN       NaN            NaN                  NaN          NaN
# 1414920        NaN       NaN            NaN                  NaN          NaN
# 1414921        NaN       NaN            NaN                  NaN          NaN
#
#         religion divorce_widow_status  health_status  \
# 0            NaN                  NaN            3.0
# 1            NaN                  NaN            4.0
# 2            NaN                  5.0            4.0
# 3            NaN                  5.0            4.0
# 4            NaN                  NaN            4.0
# ...          ...                  ...            ...
# 1414917      NaN                  5.0            2.0
# 1414918      NaN                  5.0            4.0
# 1414919      NaN                  NaN            1.0
# 1414920      NaN                  NaN            3.0
# 1414921      NaN                  5.0            3.0
#
#         health_status_compared_to_prev  high_blood_pressure  \
# 0                                  2.0                  5.0
# 1                                  3.0                  5.0
# 2                                  3.0                  5.0
# 3                                  3.0                  1.0
# 4                                  2.0                  1.0
# ...                                ...                  ...
# 1414917                            1.0                  1.0
# 1414918                            1.0                  1.0
# 1414919                            2.0                  1.0
# 1414920                            2.0                  5.0
# 1414921                            3.0                  1.0
#
#         high_blood_pressure_compared_to_prev  diabetes  \
# 0                                        NaN       5.0
# 1                                        NaN       5.0
# 2                                        NaN       5.0
# 3                                        3.0       5.0
# 4                                        2.0       5.0
# ...                                      ...       ...
# 1414917                                  1.0       5.0
# 1414918                                  NaN       1.0
# 1414919                                  1.0       5.0
# 1414920                                  NaN       5.0
# 1414921                                  1.0       5.0
#
#         diabetes_compared_to_prev  cancer cancer_compared_to_prev  \
# 0                             NaN     5.0                     NaN
# 1                             NaN     1.0                     NaN
# 2                             NaN     5.0                     NaN
# 3                             NaN     5.0                     NaN
# 4                             NaN     1.0                     8.0
# ...                           ...     ...                     ...
# 1414917                       NaN     5.0                     NaN
# 1414918                       2.0     1.0                     NaN
# 1414919                       NaN     5.0                     NaN
# 1414920                       NaN     5.0                     NaN
# 1414921                       NaN     5.0                     NaN
#
#          lung_disease lung_disease_compared_to_prev  heart_condition  \
# 0                 5.0                           NaN              1.0
# 1                 5.0                           NaN              5.0
# 2                 5.0                           NaN              5.0
# 3                 1.0                           3.0              1.0
# 4                 5.0                           NaN              5.0
# ...               ...                           ...              ...
# 1414917           5.0                           NaN              1.0
# 1414918           5.0                           NaN              5.0
# 1414919           5.0                           NaN              5.0
# 1414920           5.0                           NaN              1.0
# 1414921           5.0                           NaN              1.0
#
#         heart_condition_compared_to_prev  stroke  \
# 0                                    2.0     5.0
# 1                                    NaN     5.0
# 2                                    NaN     5.0
# 3                                    3.0     1.0
# 4                                    NaN     5.0
# ...                                  ...     ...
# 1414917                              NaN     5.0
# 1414918                              NaN     1.0
# 1414919                              NaN     5.0
# 1414920                              NaN     5.0
# 1414921                              2.0     5.0
#
#         heart_condition_compared_to_prev  psychiatric_emotional_problem  \
# 0                                    NaN                            5.0
# 1                                    NaN                            1.0
# 2                                    NaN                            4.0
# 3                                    5.0                            1.0
# 4                                    NaN                            5.0
# ...                                  ...                            ...
# 1414917                              NaN                            5.0
# 1414918                              5.0                            5.0
# 1414919                              NaN                            5.0
# 1414920                              NaN                            1.0
# 1414921                              NaN                            5.0
#
#         psychiatric_emotional_problem_compared_to_prev  arthritis  \
# 0                                                  NaN        5.0
# 1                                                  1.0        1.0
# 2                                                  NaN        5.0
# 3                                                  3.0        1.0
# 4                                                  NaN        1.0
# ...                                                ...        ...
# 1414917                                            NaN        5.0
# 1414918                                            NaN        1.0
# 1414919                                            NaN        5.0
# 1414920                                            2.0        5.0
# 1414921                                            NaN        1.0
#
#         arthritis_compared_to_prev  pain pain_degree smoke still_smoke  \
# 0                              NaN   5.0         NaN   NaN         NaN
# 1                              2.0   5.0         NaN   NaN         NaN
# 2                              NaN   5.0         NaN   NaN         NaN
# 3                              3.0   5.0         NaN   NaN         NaN
# 4                              2.0   1.0         1.0   NaN         5.0
# ...                            ...   ...         ...   ...         ...
# 1414917                        NaN   5.0         NaN   NaN         5.0
# 1414918                        NaN   1.0         2.0   NaN         5.0
# 1414919                        NaN   5.0         NaN   NaN         5.0
# 1414920                        NaN   5.0         NaN   NaN         NaN
# 1414921                        NaN   1.0         1.0   NaN         NaN
#
#          alcohol num_drinks_days_per_week num_drinks_per_day  \
# 0            1.0                      1.0                1.0
# 1            5.0                      NaN                NaN
# 2            1.0                      0.0                NaN
# 3            5.0                      NaN                NaN
# 4            1.0                      3.0                3.0
# ...          ...                      ...                ...
# 1414917      5.0                      NaN                NaN
# 1414918      1.0                      0.0                NaN
# 1414919      1.0                      3.0                3.0
# 1414920      1.0                      1.0                2.0
# 1414921      5.0                      NaN                NaN
#
#          shortness_breath  fatigue  cough depressed_x tired appetite_loss  \
# 0                     5.0      5.0    1.0         5.0   NaN           NaN
# 1                     5.0      5.0    5.0         5.0   NaN           NaN
# 2                     5.0      5.0    5.0         5.0   NaN           NaN
# 3                     1.0      5.0    1.0         1.0   1.0           5.0
# 4                     1.0      1.0    5.0         1.0   NaN           NaN
# ...                   ...      ...    ...         ...   ...           ...
# 1414917               5.0      5.0    5.0         5.0   NaN           NaN
# 1414918               5.0      5.0    1.0         5.0   NaN           NaN
# 1414919               5.0      5.0    5.0         5.0   NaN           NaN
# 1414920               5.0      5.0    5.0         5.0   NaN           NaN
# 1414921               1.0      1.0    5.0         5.0   NaN           NaN
#
#         appetite_increase memory_x depressed_y children_nearby dependents  \
# 0                     NaN      3.0         5.0             5.0        5.0
# 1                     NaN      3.0         5.0             5.0        5.0
# 2                     NaN      4.0         5.0             NaN        5.0
# 3                     1.0      1.0         5.0             NaN        5.0
# 4                     NaN      4.0         5.0             5.0        5.0
# ...                   ...      ...         ...             ...        ...
# 1414917               NaN      3.0         5.0             1.0        5.0
# 1414918               NaN      3.0         5.0             NaN        5.0
# 1414919               NaN      2.0         5.0             1.0        5.0
# 1414920               NaN      4.0         5.0             1.0        5.0
# 1414921               NaN      3.0         5.0             1.0        5.0
#
#         num_dependents type_house own_or_rent property_value  \
# 0                  NaN        2.0         1.0       250000.0
# 1                  NaN        2.0         1.0       250000.0
# 2                  NaN       97.0         1.0      1000000.0
# 3                  NaN        4.0         1.0        10000.0
# 4                  NaN        2.0         1.0       260000.0
# ...                ...        ...         ...            ...
# 1414917            NaN        4.0         2.0            NaN
# 1414918            NaN        3.0         2.0            NaN
# 1414919            NaN        2.0         1.0       380000.0
# 1414920            NaN        2.0         1.0       380000.0
# 1414921            NaN        2.0         1.0     99999999.0
#
#         year_property_acquired vocab_level friendliness cooperation tiredness  \
# 0                          NaN         2.0          5.0         3.0       1.0
# 1                          NaN         2.0          5.0         3.0       1.0
# 2                          NaN         2.0          5.0         3.0       1.0
# 3                          NaN         2.0          5.0         3.0       1.0
# 4                          NaN         2.0          5.0         3.0       1.0
# ...                        ...         ...          ...         ...       ...
# 1414917                    NaN         2.0          5.0         3.0       1.0
# 1414918                    NaN         2.0          5.0         1.0       1.0
# 1414919                    NaN         3.0          5.0         3.0       1.0
# 1414920                    NaN         3.0          5.0         2.0       1.0
# 1414921                    NaN         1.0          5.0         3.0       1.0
#
#         memory_y hearing employment_status year_retired state_live  gender  \
# 0            NaN     NaN               5.0          NaN        9.0     1.0
# 1            NaN     NaN               5.0          NaN        9.0     2.0
# 2            NaN     NaN               5.0          NaN        2.0     1.0
# 3            NaN     NaN               4.0          NaN        2.0     2.0
# 4            NaN     NaN               5.0          NaN        5.0     1.0
# ...          ...     ...               ...          ...        ...     ...
# 1414917      NaN     NaN               1.0          NaN        2.0     2.0
# 1414918      NaN     NaN               1.0          NaN        9.0     1.0
# 1414919      NaN     NaN               1.0          NaN        1.0     1.0
# 1414920      NaN     NaN               1.0          NaN        1.0     2.0
# 1414921      2.0     5.0               4.0          NaN        5.0     2.0
#
#          year_born_y leave_inheritance      income debt_amount  wave  \
# 0             1936.0               NaN         NaN         NaN   9.0
# 1             1938.0               NaN         NaN         NaN   9.0
# 2             1939.0               0.0         NaN         NaN   9.0
# 3             1956.0               NaN         NaN         NaN   9.0
# 4             1939.0               NaN         NaN         NaN   9.0
# ...              ...               ...         ...         ...   ...
# 1414917       1950.0               NaN     23093.0         NaN   9.0
# 1414918       1952.0               5.0  99999998.0         NaN   9.0
# 1414919       1949.0               NaN     23000.0         NaN   9.0
# 1414920       1949.0               NaN     23000.0         NaN   9.0
# 1414921       1953.0               NaN         NaN         NaN   9.0
#
#          Earliest_Missing_Year  Base_Year  year_death
# 0                         2014       2008         NaN
# 1                         2016       2008         NaN
# 2                            0       2008         NaN
# 3                            0       2008         NaN
# 4                         2012       2008         NaN
# ...                        ...        ...         ...
# 1414917                   2010       2008         NaN
# 1414918                      0       2008         NaN
# 1414919                      0       2008         NaN
# 1414920                      0       2008         NaN
# 1414921                      0       2008         NaN
#
# [1414922 rows x 75 columns]
